# %%
# !pip install -v ydata-profiling
# Out:
# Using pip 22.2.2 from C:\Users\hani4\anaconda3\lib\site-packages\pip (python 3.9)
# ...
#      ------------------------------------ 357.3/357.3 kB 887.6 kB/s eta 0:00:00
# ...
#      -------------------------------------- 102.7/102.7 kB 1.5 MB/s eta 0:00:00
# ...
#   Link requires a different Python (3.9.13 not in: '~=2.7, >=3.4'): https://files.pythonhosted.org/packages/29/e8/8c1c31b246a1434d7860936a49dd2e7e74f6fb5f169b6e288308b3f37adf/multimethod-0.7-py2.py3-none-any.whl (from https://pypi.org/simple/multimethod/) (requires-python:~=2.7, >=3.4)
#   Link requires a different Python (3.9.13 not in: '~=2.7, >=3.4'): https://files.pythonhosted.org/packages/5c/29/f8b101ed29ac77e7298b57600550c8f211e02179785581eff7d0a6728a41/multimethod-0.7.tar.gz (from https://pypi.org/simple/multimethod/) (requires-python:~=2.7, >=3.4)
# ...
#      -------------------------------------- 663.5/663.5 kB 1.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 296.5/296.5 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('data/saudi-pro-league-transfers.csv')

profile = ProfileReport(df, title="Profile Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.5.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-09-27 19:01:54.427207&quot;&gt;&lt;title&gt;Profile Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
